# %%
import pandas as pd

columns = ["year", "stage", "group", "home_team", "away_team"]
data = []

def add_match(data, year, stage, group, home_team, away_team):
        data.append({"year": year, "stage": stage, "group": group, "home_team": home_team, "away_team": away_team})

#Group A
add_match(data, 2026, "Group Stage", "Group A", "Mexico", "South Africa")
add_match(data, 2026, "Group Stage", "Group A", "South Korea", "Czech Republic")
add_match(data, 2026, "Group Stage", "Group A", "Czech Republic", "South Africa")
add_match(data, 2026, "Group Stage", "Group A", "Mexico", "South Korea")
add_match(data, 2026, "Group Stage", "Group A", "Czech Republic", "Mexico")
add_match(data, 2026, "Group Stage", "Group A", "South Africa", "South Korea")

#Group B
add_match(data, 2026, "Group Stage", "Group B", "Canada", "Bosnia and Herzegovina")
add_match(data, 2026, "Group Stage", "Group B", "Qatar", "Switzerland")
add_match(data, 2026, "Group Stage", "Group B", "Switzerland", "Bosnia and Herzegovina")
add_match(data, 2026, "Group Stage", "Group B", "Canada", "Qatar")
add_match(data, 2026, "Group Stage", "Group B", "Switzerland", "Canada")
add_match(data, 2026, "Group Stage", "Group B", "Bosnia and Herzegovina", "Qatar")

#Group C
add_match(data, 2026, "Group Stage", "Group C", "Brazil", "Morocco")
add_match(data, 2026, "Group Stage", "Group C", "Haiti", "Scotland")
add_match(data, 2026, "Group Stage", "Group C", "Scotland", "Morocco")
add_match(data, 2026, "Group Stage", "Group C", "Brazil", "Haiti")
add_match(data, 2026, "Group Stage", "Group C", "Scotland", "Brazil")
add_match(data, 2026, "Group Stage", "Group C", "Morocco", "Haiti")

#Group D
add_match(data, 2026, "Group Stage", "Group D", "United States", "Paraguay")
add_match(data, 2026, "Group Stage", "Group D", "Australia", "Turkey")
add_match(data, 2026, "Group Stage", "Group D", "United States", "Australia")
add_match(data, 2026, "Group Stage", "Group D", "Turkey", "Paraguay")
add_match(data, 2026, "Group Stage", "Group D", "Turkey", "United States")
add_match(data, 2026, "Group Stage", "Group D", "Paraguay", "Australia")

#Group E
add_match(data, 2026, "Group Stage", "Group E", "Germany", "Curaçao")
add_match(data, 2026, "Group Stage", "Group E", "Ivory Coast", "Ecuador")
add_match(data, 2026, "Group Stage", "Group E", "Germany", "Ivory Coast")
add_match(data, 2026, "Group Stage", "Group E", "Ecuador", "Curaçao")
add_match(data, 2026, "Group Stage", "Group E", "Curaçao", "Ivory Coast")
add_match(data, 2026, "Group Stage", "Group E", "Ecuador", "Germany")

#Group F
add_match(data, 2026, "Group Stage", "Group F", "Netherlands", "Japan")
add_match(data, 2026, "Group Stage", "Group F", "Sweden", "Tunisia")
add_match(data, 2026, "Group Stage", "Group F", "Netherlands", "Sweden")
add_match(data, 2026, "Group Stage", "Group F", "Tunisia", "Japan")
add_match(data, 2026, "Group Stage", "Group F", "Japan", "Sweden")
add_match(data, 2026, "Group Stage", "Group F", "Tunisia", "Netherlands")

#Group G
add_match(data, 2026, "Group Stage", "Group G", "Belgium", "Egypt")
add_match(data, 2026, "Group Stage", "Group G", "Iran", "New Zealand")
add_match(data, 2026, "Group Stage", "Group G", "Belgium", "Iran")
add_match(data, 2026, "Group Stage", "Group G", "New Zealand", "Egypt")
add_match(data, 2026, "Group Stage", "Group G", "Egypt", "Iran")
add_match(data, 2026, "Group Stage", "Group G", "New Zealand", "Belgium")

#Group H
add_match(data, 2026, "Group Stage", "Group H", "Spain", "Cape Verde")
add_match(data, 2026, "Group Stage", "Group H", "Saudi Arabia", "Uruguay")
add_match(data, 2026, "Group Stage", "Group H", "Spain", "Saudi Arabia")
add_match(data, 2026, "Group Stage", "Group H", "Uruguay", "Cape Verde")
add_match(data, 2026, "Group Stage", "Group H", "Cape Verde", "Saudi Arabia")
add_match(data, 2026, "Group Stage", "Group H", "Uruguay", "Spain")

#Group I
add_match(data, 2026, "Group Stage", "Group I", "France", "Senegal")
add_match(data, 2026, "Group Stage", "Group I", "Iraq", "Norway")
add_match(data, 2026, "Group Stage", "Group I", "France", "Iraq")
add_match(data, 2026, "Group Stage", "Group I", "Norway", "Senegal")
add_match(data, 2026, "Group Stage", "Group I", "Norway", "France")
add_match(data, 2026, "Group Stage", "Group I", "Senegal", "Iraq")

#Group J
add_match(data, 2026, "Group Stage", "Group J", "Argentina", "Algeria")
add_match(data, 2026, "Group Stage", "Group J", "Austria", "Jordan")
add_match(data, 2026, "Group Stage", "Group J", "Argentina", "Austria")
add_match(data, 2026, "Group Stage", "Group J", "Jordan", "Algeria")
add_match(data, 2026, "Group Stage", "Group J", "Algeria", "Austria")
add_match(data, 2026, "Group Stage", "Group J", "Jordan", "Argentina")

#Group K
add_match(data, 2026, "Group Stage", "Group K", "Portugal", "DR Congo")
add_match(data, 2026, "Group Stage", "Group K", "Uzbekistan", "Colombia")
add_match(data, 2026, "Group Stage", "Group K", "Portugal", "Uzbekistan")
add_match(data, 2026, "Group Stage", "Group K", "Colombia", "DR Congo")
add_match(data, 2026, "Group Stage", "Group K", "Colombia", "Portugal")
add_match(data, 2026, "Group Stage", "Group K", "DR Congo", "Uzbekistan")

#Group L
add_match(data, 2026, "Group Stage", "Group L", "England", "Croatia")
add_match(data, 2026, "Group Stage", "Group L", "Ghana", "Panama")
add_match(data, 2026, "Group Stage", "Group L", "England", "Ghana")
add_match(data, 2026, "Group Stage", "Group L", "Panama", "Croatia")
add_match(data, 2026, "Group Stage", "Group L", "Panama", "England")
add_match(data, 2026, "Group Stage", "Group L", "Croatia", "Ghana")

df = pd.DataFrame(data, columns=columns)
df.to_csv("current_tournament.csv", index=False)
